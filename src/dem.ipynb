# %%
import os 
os.chdir('../data/dem')

# %%
import rasterio as rs
import matplotlib.pyplot as plt
import georaster
from rasterio.plot import show
import cv2
import numpy as np

import geopandas
import os

# %%
os.listdir()
# Out:
# ['DEM_elevation.tif', 'DEM_slope.tif']

# %%
from scipy import ndimage
import imageio
img = np.asarray(imageio.imread('DEM_elevation.tif'))

plt.imshow(img)
